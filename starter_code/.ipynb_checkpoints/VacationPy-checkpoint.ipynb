# 544       Cedar City      US  37.6775 -113.0619  1622659917          31.33
# 545           Touros      BR  -5.1989  -35.4608  1622659630          30.50
# 546         Barranca      PE -10.7500  -77.7667  1622659918          20.62
# 547       Djebeniana      TN  35.0350   10.9081  1622659918          23.89
# 548  Medvezh'yegorsk      RU  62.9167   34.4667  1622659918          13.51
# 549            Bilma      NE  18.6853   12.9164  1622659919          35.15
# 550          Gazojak      TM  41.1875   61.4036  1622659919          32.90
# 551         Klaksvík      FO  62.2266   -6.5890  1622659919          10.51
# 552          Sonoita      MX  31.8500 -112.8333  1622659919          36.41
# 553         Naivasha      KE  -0.7167   36.4359  1622659920          16.17
# 554           Noumea      NC -22.2763  166.4572  1622659920          19.44
# 555      Henties Bay     NaN -22.1160   14.2845  1622659921          17.70
# 556       Oranjemund     NaN -28.5500   16.4333  1622659921          15.06
#
#      Humidity  Cloudiness  Wind Speed (mph)
# 0          77          40              0.89
# 1          82          30              2.66
# 2          88          94              4.67
# 3          90          13              3.03
# 4          84          27              1.48
# 5          75          35              2.41
# 6          65          75             12.35
# 7          79         100              2.66
# 8          84          97              6.94
# 9          38          36              3.63
# 10         73           0              4.63
# 11         73          19              0.98
# 12         89         100              1.96
# 13         19         100              2.33
# 14         71          75              4.12
# 15         86          90              2.57
# 16         89          42              1.27
# 17         46          40              6.69
# 18         74         100              2.05
# 19         86          94              1.93
# 20         53         100              2.19
# 21         93          31              2.45
# 22         95          26              0.74
# 23         55          50              3.13
# 24         72           2              1.09
# 25         93          90              4.63
# 26         50          40              1.34
# 27         95          90              0.45
# 28         82           0              6.69
# 29         70          16              3.68
# ..        ...         ...               ...
# 527        83           4              1.66
# 528        83          86              1.10
# 529        79           9              3.21
# 530        17           0              2.15
# 531        25           1              2.24
# 532        65          49              3.80
# 533        51          66              6.25
# 534        64          22              3.98
# 535        94          99              2.27
# 536        57          31              1.62
# 537        83          75              2.65
# 538        96          50              2.95
# 539        10           0              4.03
# 540        59         100              3.42
# 541        59          40              5.66
# 542        28           0              3.60
# 543        97         100              1.41
# 544         8           1              2.57
# 545        67           4              6.89
# 546        70          74              3.44
# 547        82         100              4.05
# 548        64          97              2.03
# 549         9          15              1.88
# 550        19           0              4.90
# 551        95         100              3.82
# 552        13           6              4.53
# 553        91          38              1.99
# 554        99          39              2.87
# 555        55           0              3.81
# 556        61           0              5.88
#
# [557 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
s1_df= city_df.loc[((city_df['Max Temp (cs)'] >= 21) & (city_df['Max Temp (cs)'] <= 26))]
s2_df= s1_df.loc[(s1_df['Wind Speed (mph)'] <= 10)]
s3_df= s2_df.loc[(s2_df['Cloudiness'] == 0)]
s3_df
# Out:
#                       City Country      Lat      Lon        Date  \
# 49                 Kajaani      FI  64.2273  27.7285  1622659773
# 108                   Jaen      ES  38.0000  -3.5000  1622659790
# 181                  Aktau      KZ  43.6500  51.2000  1622659811
# 274  San Miguel de Tucumán      AR -26.8241 -65.2226  1622659808
# 284                 Boysun      UZ  38.2061  67.1986  1622659840
# 317             Uruguaiana      BR -29.7547 -57.0883  1622659850
# 330                 Harsīn      IR  34.2721  47.5861  1622659854
# 334                   Aras      ES  42.5617  -2.3560  1622659855
# 484                 Luanda      AO  -8.8368  13.2343  1622659807
#
#      Max Temp (cs)  Humidity  Cloudiness  Wind Speed (mph)
# 49           21.03        35           0              1.54
# 108          25.52        24           0              3.94
# 181          22.32        73           0              5.35
# 274          23.00        46           0              2.46
# 284          24.81        20           0              3.58
# 317          21.96        49           0              6.69
# 330          23.45        26           0              1.61
# 334          24.23        44           0              1.54
# 484          25.00        83           0              3.09

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = s3_df
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       City Country      Lat      Lon        Date  \
# 49                 Kajaani      FI  64.2273  27.7285  1622659773
# 108                   Jaen      ES  38.0000  -3.5000  1622659790
# 181                  Aktau      KZ  43.6500  51.2000  1622659811
# 274  San Miguel de Tucumán      AR -26.8241 -65.2226  1622659808
# 284                 Boysun      UZ  38.2061  67.1986  1622659840
# 317             Uruguaiana      BR -29.7547 -57.0883  1622659850
# 330                 Harsīn      IR  34.2721  47.5861  1622659854
# 334                   Aras      ES  42.5617  -2.3560  1622659855
# 484                 Luanda      AO  -8.8368  13.2343  1622659807
#
#      Max Temp (cs)  Humidity  Cloudiness  Wind Speed (mph) Hotel Name
# 49           21.03        35           0              1.54
# 108          25.52        24           0              3.94
# 181          22.32        73           0              5.35
# 274          23.00        46           0              2.46
# 284          24.81        20           0              3.58
# 317          21.96        49           0              6.69
# 330          23.45        26           0              1.61
# 334          24.23        44           0              1.54
# 484          25.00        83           0              3.09

# %%
# params dictionary to update each iteration
params = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key
}

# Use the lat/lon we recovered to identify hotels
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lon = row["Lon"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lon}"

    #set base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)

    # convert to json
    name_address = name_address.json()

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        print(f'adding data for row {index}')
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# adding data for row 49
# adding data for row 108
# adding data for row 181
# adding data for row 274
# adding data for row 284
# adding data for row 317
# adding data for row 330
# Missing field/result... skipping.
# adding data for row 334
# adding data for row 484

# %%
hotel_df
# Out:
#                       City Country      Lat      Lon        Date  \
# 49                 Kajaani      FI  64.2273  27.7285  1622659773
# 108                   Jaen      ES  38.0000  -3.5000  1622659790
# 181                  Aktau      KZ  43.6500  51.2000  1622659811
# 274  San Miguel de Tucumán      AR -26.8241 -65.2226  1622659808
# 284                 Boysun      UZ  38.2061  67.1986  1622659840
# 317             Uruguaiana      BR -29.7547 -57.0883  1622659850
# 330                 Harsīn      IR  34.2721  47.5861  1622659854
# 334                   Aras      ES  42.5617  -2.3560  1622659855
# 484                 Luanda      AO  -8.8368  13.2343  1622659807
#
#      Max Temp (cs)  Humidity  Cloudiness  Wind Speed (mph)  \
# 49           21.03        35           0              1.54
# 108          25.52        24           0              3.94
# 181          22.32        73           0              5.35
# 274          23.00        46           0              2.46
# 284          24.81        20           0              3.58
# 317          21.96        49           0              6.69
# 330          23.45        26           0              1.61
# 334          24.23        44           0              1.54
# 484          25.00        83           0              3.09
#
#                       Hotel Name
# 49   Original Sokos Hotel Valjus
# 108              Hotel TRH Baeza
# 181      Renaissance Aktau Hotel
# 274       Sheraton Tucuman Hotel
# 284                   Gaza Hotel
# 317             Hotel Presidente
# 330
# 334    Palacio de Pujadas by MIJ
# 484             EPIC SANA Luanda

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lon"]]

# %%
# Add marker layer ontop of heat map


# Display figure
